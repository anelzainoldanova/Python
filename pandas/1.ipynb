# %%
import pandas as pd
import numpy as np
data = pd.read_csv('20221013_ted_talks.csv')

# %%
data
# Out:
#       talk_id                                           title  \
# 0           1                     Averting the climate crisis
# 1           7                                Simplicity sells
# 2          53                             Greening the ghetto
# 3          92                 The best stats you've ever seen
# 4          66                     Do schools kill creativity?
# ...       ...                                             ...
# 5696    98707                       Is inequality inevitable?
# 5697    98662   4 ways to design a disability-friendly future
# 5698    98383  Can exercise actually "boost" your metabolism?
# 5699    98706   How did they build the Great Pyramid of Giza?
# 5700    98843  How to squeeze all the juice out of retirement
#
#                   speaker recorded_date published_date  \
# 0                 Al Gore    2006-02-25     2006-06-27
# 1             David Pogue    2006-02-24     2006-06-27
# ...

# %%
data.head(2)
# Out:
#    talk_id                        title      speaker recorded_date  \
# 0        1  Averting the climate crisis      Al Gore    2006-02-25
# 1        7             Simplicity sells  David Pogue    2006-02-24
#
#   published_date    event  duration    views   likes
# 0     2006-06-27  TED2006       957  3681537  110000
# 1     2006-06-27  TED2006      1266  2012797   60000

# %%
data.tail(3)
# Out:
#       talk_id                                           title  \
# 5698    98383  Can exercise actually "boost" your metabolism?
# 5699    98706   How did they build the Great Pyramid of Giza?
# 5700    98843  How to squeeze all the juice out of retirement
#
#                   speaker recorded_date published_date  \
# 5698           Jen Gunter    2022-10-12     2022-10-12
# 5699  Soraya Field Fiorio    2022-10-13     2022-10-13
# 5700         Riley Moynes    2022-02-19     2022-10-13
#
#                                event  duration   views  likes
# 5698  Body Stuff with Dr. Jen Gunter       210   30087    902
# 5699                          TED-Ed       332     456     13
# 5700                      TEDxSurrey       743  131908   3900

# %%
data.shape
# Out:
# (5701, 9)

# %%
import matplotlib.pyplot as plt
plt.plot(data['likes'], data['views'])
plt.title('Analise')
plt.grid(True)
plt.show()

# %%
plt.hist(data['likes'], len(data['views']))
plt.grid(True)
plt.show()

# %%
data.sort_values('likes', ascending=False)
# Out:
#       talk_id                                              title  \
# 4          66                        Do schools kill creativity?
# 2150     2458         Inside the mind of a master procrastinator
# 1339     1569           Your body language may shape who you are
# 672       848                   How great leaders inspire action
# 831      1042                         The power of vulnerability
# ...       ...                                                ...
# 4314    53588  "Jamie Raeburn" / "Baloo Baleerie" / "Twa recr...
# 3460    31245  "Part II. The Journey Through Time" / "Ruslan ...
# 5660    97698  How our dependence on fossil fuels is leading ...
# 2084     2386                                 Year In Ideas 2015
# 5699    98706      How did they build the Great Pyramid of Giza?
#
#                                speaker recorded_date published_date  \
# 4                     Sir Ken Robinson    2006-02-25     2006-06-27
# ...

# %%
data[data['likes']<100000]
# Out:
#       talk_id                                           title  \
# 1           7                                Simplicity sells
# 2          53                             Greening the ghetto
# 6          49          Behind the design of Seattle's library
# 9          54    My wish: A call for open-source architecture
# 10         55                   My wish: A global day of film
# ...       ...                                             ...
# 5696    98707                       Is inequality inevitable?
# 5697    98662   4 ways to design a disability-friendly future
# 5698    98383  Can exercise actually "boost" your metabolism?
# 5699    98706   How did they build the Great Pyramid of Giza?
# 5700    98843  How to squeeze all the juice out of retirement
#
#                   speaker recorded_date published_date  \
# 1             David Pogue    2006-02-24     2006-06-27
# 2           Majora Carter    2006-02-26     2006-06-27
# ...

# %%
data["event"].value_counts()
# Out:
# TED-Ed               890
# TED2018              104
# TED2020              102
# TED2019              101
# TED2017               97
#                     ...
# TEDxEastEnd            1
# TEDActive 2015         1
# Global Witness         1
# TEDxCreativeCoast      1
# TEDxSurrey             1
# Name: event, Length: 637, dtype: int64

# %%
data["speaker"].value_counts()
# Out:
# Alex Gendler               47
# Iseult Gillespie           37
# Matt Walker                18
# Alex Rosenthal             15
# Elizabeth Cox              15
#                            ..
# Anote Tong                  1
# Genevieve von Petzinger     1
# Ann Morgan                  1
# Regina Hartley              1
# Riley Moynes                1
# Name: speaker, Length: 4637, dtype: int64

# %%
data.loc[data["speaker"] == "Alex Rosenthal", "likes"].value_counts()
# Out:
# 13000     3
# 14000     2
# 16000     2
# 45000     1
# 20000     1
# 214000    1
# 10000     1
# 9300      1
# 19000     1
# 29000     1
# 18000     1
# Name: likes, dtype: int64

# %%
data.loc[data['event'] == 'TED-Ed', 'views'].max()
# Out:
# 27780198

# %%
data.loc[data['event'] == 'TED-Ed', 'views'].min()
# Out:
# 456
